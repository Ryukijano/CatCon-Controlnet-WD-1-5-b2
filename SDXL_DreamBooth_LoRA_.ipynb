# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryukijano/CatCon-Controlnet-WD-1-5-b2/blob/main/SDXL_DreamBooth_LoRA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fine-tuning Stable Diffusion XL with DreamBooth and LoRA on a free-tier Colab Notebook 🧨
#
# In this notebook, we show how to fine-tune [Stable Diffusion XL (SDXL)](https://huggingface.co/docs/diffusers/main/en/api/pipelines/stable_diffusion/stable_diffusion_xl) with [DreamBooth](https://huggingface.co/docs/diffusers/main/en/training/dreambooth) and [LoRA](https://huggingface.co/docs/diffusers/main/en/training/lora) on a T4 GPU.
#
# SDXL consists of a much larger UNet and two text encoders that make the cross-attention context quite larger than the previous variants.
#
# So, to pull this off, we will make use of several tricks such as gradient checkpointing, mixed-precision, and 8-bit Adam. So, hang tight and let's get started 🧪

# %% [markdown]
# ## Setup 🪓

# %%
# Check the GPU
# !nvidia-smi
# Out:
# Sat Aug 12 16:56:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install dependencies.
# !pip install xformers bitsandbytes transformers accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 51.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.3 MB/s eta 0:00:00

# %% [markdown]
# Make sure to install `diffusers` from `main`.

# %%
# !pip install git+https://github.com/huggingface/diffusers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done

# %% [markdown]
# Download `diffusers` SDXL DreamBooth training script.

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Out:
# --2023-08-12 16:57:07--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57305 (56K) [text/plain]
# Saving to: ‘train_dreambooth_lora_sdxl.py’
#
# train_dreambooth_lo 100%[===================>]  55.96K  --.-KB/s    in 0.01s
#
# 2023-08-12 16:57:07 (4.77 MB/s) - ‘train_dreambooth_lora_sdxl.py’ saved [57305/57305]

# %% [markdown]
# ## Dataset 🐶

# %% [markdown]
# Let's download some example images:

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir, repo_type="dataset",
    ignore_patterns=".gitattributes",
)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading (…)Hv4fbg-unsplash.jpeg:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# Downloading (…)CbNq3g-unsplash.jpeg:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# Downloading (…)8ikwFE-unsplash.jpeg:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# Downloading (…)jb-cpA-unsplash.jpeg:   0%|          | 0.00/677k [00:00<?, ?B/s]
# Downloading (…)7qszSY-unsplash.jpeg:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# '/content/dog'

# %% [markdown]
# Preview the images:

# %%
from PIL import Image

def image_grid(imgs, rows, cols, resize=256):
    assert len(imgs) == rows * cols

    if resize is not None:
        imgs = [img.resize((resize, resize)) for img in imgs]
    w, h = imgs[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols * w, i // cols * h))
    return grid

# %%
import glob

imgs = [Image.open(path) for path in glob.glob("./dog/*.jpeg")]
image_grid(imgs, 1, 5)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x256>

# %% [markdown]
# ## Prep for training 💻

# %% [markdown]
# Initialize `accelerate`:

# %%
# !accelerate config default
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-08-12 16:57:24.221708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# Make sure to log into [your Hugging Face account](https://huggingface.co/) and pass [your access token](https://huggingface.co/docs/hub/security-tokens) so that we can push the trained checkpoints to the Hugging Face Hub:

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Train! 🔬

# %% [markdown]
# Alright let's launch a training. Make sure to add `push_to_hub` so that the checkpoint is automatically pushed to the Hub and doesn't get lost.
#
# To ensure we can DreamBooth with LoRA on a heavy pipeline like Stable Diffusion XL, we're using:
#
# * Gradient checkpointing (`--gradient_accumulation_steps`)
# * Memory-efficient attention (`--enable_xformers_memory_efficient_attention`)
# * 8-bit Adam (`--use_8bit_adam`)
# * Mixed-precision training (`--mixed-precision="fp16"`)
#
# The `--push_to_hub` argument ensures that the trained checkpoints are automatically pushed to the Hugging Face Hub.

# %%
#!/usr/bin/env bash
# !accelerate launch train_dreambooth_lora_sdxl.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \
  --pretrained_vae_model_name_or_path="madebyollin/sdxl-vae-fp16-fix" \
  --instance_data_dir="dog" \
  --output_dir="lora-trained-xl-colab" \
  --mixed_precision="fp16" \
  --instance_prompt="a photo of an elf from baldurs gate" \
  --resolution=1024 \
  --train_batch_size=2 \
  --gradient_accumulation_steps=2 \
  --gradient_checkpointing \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --enable_xformers_memory_efficient_attention \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --max_train_steps=500 \
  --checkpointing_steps=717 \
  --seed="0" \
  --push_to_hub
# Out:
# 2023-08-12 17:00:03.747347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-08-12 17:00:09.554589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 08/12/2023 17:00:12 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# Downloading (…)okenizer_config.json: 100% 737/737 [00:00<00:00, 2.77MB/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 10.0MB/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 8.44MB/s]
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 1.82MB/s]
# Downloading (…)okenizer_config.json: 100% 725/725 [00:00<00:00, 2.87MB/s]
# Downloading (…)cial_tokens_map.json: 100% 460/460 [00:00<00:00, 2.24MB/s]
# Downloading (…)_encoder/config.json: 100% 565/565 [00:00<00:00, 245kB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# Downloading (…)ncoder_2/config.json: 100% 575/575 [00:00<00:00, 3.27MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# Downloading (…)cheduler_config.json: 100% 479/479 [00:00<00:00, 1.96MB/s]
# {'dynamic_thresholding_ratio', 'variance_type', 'thresholding', 'clip_sample_range'} was not found in config. Values will be initialized to default values.
# Downloading model.safetensors: 100% 492M/492M [00:21<00:00, 23.4MB/s]
# Downloading model.safetensors: 100% 2.78G/2.78G [01:28<00:00, 31.3MB/s]
# Downloading (…)lve/main/config.json: 100% 631/631 [00:00<00:00, 2.62MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:09<00:00, 33.9MB/s]
# Downloading (…)ain/unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 6.86MB/s]
# Downloading (…)ch_model.safetensors: 100% 10.3G/10.3G [05:41<00:00, 30.0MB/s]
# 08/12/2023 17:09:09 - INFO - __main__ - ***** Running training *****
# 08/12/2023 17:09:09 - INFO - __main__ -   Num examples = 5
# 08/12/2023 17:09:09 - INFO - __main__ -   Num batches each epoch = 3
# 08/12/2023 17:09:09 - INFO - __main__ -   Num Epochs = 250
# 08/12/2023 17:09:09 - INFO - __main__ -   Instantaneous batch size per device = 2
# 08/12/2023 17:09:09 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 08/12/2023 17:09:09 - INFO - __main__ -   Gradient Accumulation steps = 2
# 08/12/2023 17:09:09 - INFO - __main__ -   Total optimization steps = 500
# Steps: 100% 500/500 [1:11:06<00:00,  7.72s/it, loss=0.00357, lr=0.0001]Model weights saved in lora-trained-xl-colab/pytorch_lora_weights.bin
#
# Downloading (…)ain/model_index.json: 100% 609/609 [00:00<00:00, 3.25MB/s]
#
# Fetching 17 files:   0% 0/17 [00:00<?, ?it/s]
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:06, 48.9MB/s]
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:06, 47.6MB/s]
#
# Downloading (…)ch_model.safetensors:   9% 31.5M/335M [00:00<00:06, 45.2MB/s]
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:01<00:07, 37.9MB/s]
#
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:01<00:07, 39.1MB/s]
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:01<00:06, 43.1MB/s]
#
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:01<00:05, 46.3MB/s]
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:01<00:05, 46.4MB/s]
#
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:02<00:05, 42.4MB/s]
#
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:02<00:05, 39.0MB/s]
#
# Downloading (…)ch_model.safetensors:  34% 115M/335M [00:02<00:06, 33.5MB/s]
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:03<00:06, 30.0MB/s]
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:03<00:06, 29.3MB/s]
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:04<00:06, 29.8MB/s]
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:04<00:05, 31.6MB/s]
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:04<00:05, 31.3MB/s]
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:04<00:04, 33.7MB/s]
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:05<00:03, 36.7MB/s]
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:05<00:03, 38.1MB/s]
#
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:05<00:03, 38.6MB/s]
#
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:06<00:03, 35.1MB/s]
#
# Downloading (…)ch_model.safetensors:  69% 231M/335M [00:06<00:02, 36.8MB/s]
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:06<00:02, 37.2MB/s]
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:06<00:02, 36.0MB/s]
#
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:07<00:01, 38.7MB/s]
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:07<00:01, 36.3MB/s]
#
# Downloading (…)ch_model.safetensors:  85% 283M/335M [00:07<00:01, 34.0MB/s]
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:08<00:01, 35.3MB/s]
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:08<00:00, 36.4MB/s]
#
# Downloading (…)ch_model.safetensors:  94% 315M/335M [00:08<00:00, 32.3MB/s]
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:09<00:00, 31.6MB/s]
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:09<00:00, 35.2MB/s]
#
# Fetching 17 files: 100% 17/17 [00:09<00:00,  1.73it/s]
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:00,  6.33it/s]Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  57% 4/7 [00:03<00:02,  1.10it/s]Loaded unet as UNet2DConditionModel from `unet` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  71% 5/7 [00:57<00:31, 15.79s/it]Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  86% 6/7 [01:13<00:15, 15.76s/it]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100% 7/7 [01:13<00:00, 10.51s/it]
# {'solver_type', 'algorithm_type', 'solver_order', 'variance_type', 'lower_order_final', 'dynamic_thresholding_ratio', 'thresholding', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Loading unet.
#
# Upload 3 LFS files:   0% 0/3 [00:00<?, ?it/s]
#
# events.out.tfevents.1691860149.b5856a8759c1.4142.0:   0% 0.00/62.7k [00:00<?, ?B/s]
#
#
# events.out.tfevents.1691860149.b5856a8759c1.4142.1:   0% 0.00/2.73k [00:00<?, ?B/s]
#
#
#
# pytorch_lora_weights.bin:   0% 0.00/23.7M [00:00<?, ?B/s]
#
#
# events.out.tfevents.1691860149.b5856a8759c1.4142.1: 100% 2.73k/2.73k [00:00<00:00, 6.72kB/s]
#
#
#
# pytorch_lora_weights.bin:   0% 16.4k/23.7M [00:00<09:50, 40.0kB/s]
#
# events.out.tfevents.1691860149.b5856a8759c1.4142.1: 100% 2.73k/2.73k [00:00<00:00, 5.88kB/s]
#
#
#
#
# events.out.tfevents.1691860149.b5856a8759c1.4142.0: 100% 62.7k/62.7k [00:00<00:00, 109kB/s]
#
#
#
#
# pytorch_lora_weights.bin:  25% 5.83M/23.7M [00:00<00:01, 14.6MB/s]
#
#
#
# pytorch_lora_weights.bin:  62% 14.7M/23.7M [00:00<00:00, 34.0MB/s]
# Upload 3 LFS files:  33% 1/3 [00:00<00:01,  1.31it/s]
# Upload 3 LFS files:  67% 2/3 [00:00<00:00,  2.33it/s]
#
#
#
# pytorch_lora_weights.bin:  82% 19.4M/23.7M [00:02<00:00, 6.35MB/s]
#
#
#
# pytorch_lora_weights.bin: 100% 23.7M/23.7M [00:03<00:00, 7.74MB/s]
#
# Upload 3 LFS files: 100% 3/3 [00:03<00:00,  1.12s/it]
# Steps: 100% 500/500 [1:12:37<00:00,  8.71s/it, loss=0.00357, lr=0.0001]

# %% [markdown]
# Cool the model has been uploaded to https://huggingface.co/sayakpaul/lora-trained-xl-colab 🔥🚀
#
# Let's generate some images with it!

# %% [markdown]
# ## Inference 🐕

# %%
from diffusers import DiffusionPipeline
import torch

from diffusers import DiffusionPipeline, AutoencoderKL

vae = AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    vae=vae, torch_dtype=torch.float16, variant="fp16",
    use_safetensors=True
)
pipe.load_lora_weights("sayakpaul/lora-trained-xl-colab")

_ = pipe.to("cuda")
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# Downloading model.fp16.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading (…)rch_lora_weights.bin:   0%|          | 0.00/23.7M [00:00<?, ?B/s]

# %%
prompt = "a photo of sks dog in a bucket"

image = pipe(prompt=prompt, num_inference_steps=25).images[0]
image
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>
